# %%
import os
from typing import List

import numpy as np

os.environ["DGLBACKEND"] = "pytorch"
import dgl
import dgl.data
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F

import data

# %%
graph = data.get_dataset('amazon', "../datasets")

graph
# Out:
# Graph(num_nodes={'user': 11944},
#       num_edges={('user', 'net_upu', 'user'): 351216, ('user', 'net_usu', 'user'): 7132958, ('user', 'net_uvu', 'user'): 2073474},
#       metagraph=[('user', 'user', 'net_upu'), ('user', 'user', 'net_usu'), ('user', 'user', 'net_uvu')])

# %%
graph.out_edges(0)
# Out:
# ---------------------------------------------------------------------------
# DGLError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 graph.out_edges(0)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\dgl\heterograph.py:3504, in DGLGraph.out_edges(self, u, form, etype)
#    3431 """Return the outgoing edges of the given nodes.
#    3432
#    3433 Parameters
#    (...)
#    3501 in_edges
#    3502 """
#    3503 u = utils.prepare_tensor(self, u, "u")
# -> 3504 srctype, _, _ = self.to_canonical_etype(etype)
#    3505 if F.as_scalar(F.sum(self.has_nodes(u, ntype=srctype), dim=0)) != len(
#    3506     u
#    3507 ):
#    3508     raise DGLError("u contains invalid node IDs")
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\dgl\heterograph.py:1279, in DGLGraph.to_canonical_etype(self, etype)
#    1277 if etype is None:
#    1278     if len(self.etypes) != 1:
# -> 1279         raise DGLError(
#    1280             "Edge type name must be specified if there are more than one "
#    1281             "edge types."
#    1282         )
#    1283     etype = self.etypes[0]
#    1284 if isinstance(etype, tuple):
#
# DGLError: Edge type name must be specified if there are more than one edge types.

# %%
from modules.mlp_layer import CustomMLP
from torchview import draw_graph

custom_mlp = CustomMLP(10, 5, 2)

visualize = draw_graph(custom_mlp, torch.zeros((1, 10)))

visualize.visual_graph
# Out:
# (dot.exe:16792): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
